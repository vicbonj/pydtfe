# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage.filters import gaussian_filter
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.animation as animation
# %matplotlib inline

# %% [markdown]
# ## Start by importing the module pydtfe

# %%
from pydtfe import map_dtfe3d

# %% [markdown]
# ## Then create a fake distribution of points

# %%
nb_points=500
sample_test=np.random.randn(nb_points,3)
x,y,z=sample_test[:,0],sample_test[:,1],sample_test[:,2]

# %% [markdown]
# ## One can look at the distribution you've just made

# %%
fig=plt.figure(1,figsize=(8,8))
ax=fig.add_subplot(111,projection='3d')
ax.scatter(x,y,z)

# %% [markdown]
# ## Define a size for your map...

# %%
size=300

# %% [markdown]
# ## ... and run the function map_dtfe

# %%
grid=map_dtfe3d(x,y,z,size)

# %% [markdown]
# ## You can smooth your map to avoid geometrical effects of Delaunay tesselation

# %%
std_in_pixel=0.01*size # here a standard deviation in pixels
smooth_grid=gaussian_filter(grid,std_in_pixel)

# %% [markdown]
# ## And now you can look at your density maps

# %%
i=int(size/2) #indice of the slice in the z direction (deepness)
plt.figure()
plt.imshow(smooth_grid[:,:,250],interpolation='None',origin='lower',vmin=0,vmax=5*np.std(smooth_grid),extent=[x.min(),x.max(),y.min(),y.max()])

# %% [markdown]
# ## You can trace the density through the deepness axis for pixels or regions

# %%
x=int(size/2)
y=int(size/2)
plt.figure()
plt.plot(np.arange(size),grid[x,y,:])
